# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
mydata=pd.read_csv("http://bit.ly/movieusers",sep="|",header=None)
print(mydata.head(20))
# Out:
#      0   1  2              3      4
# 0    1  24  M     technician  85711
# 1    2  53  F          other  94043
# 2    3  23  M         writer  32067
# 3    4  24  M     technician  43537
# 4    5  33  F          other  15213
# 5    6  42  M      executive  98101
# 6    7  57  M  administrator  91344
# 7    8  36  M  administrator  05201
# 8    9  29  M        student  01002
# 9   10  53  M         lawyer  90703
# 10  11  39  F          other  30329
# 11  12  28  F          other  06405
# 12  13  47  M       educator  29206
# 13  14  45  M      scientist  55106
# 14  15  49  F       educator  97301
# 15  16  21  M  entertainment  10309
# 16  17  30  M     programmer  06355
# 17  18  35  F          other  37212
# 18  19  40  M      librarian  02138
# 19  20  42  F      homemaker  95660

# %%
mydata.columns=["col1","col2","col3","col4","col5"]
#print(mydata.col3)
mydata['col6']=mydata["col2"].map(str)+":"+mydata["col3"]
print(type(mydata))
print(mydata.columns.tolist())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ['col1', 'col2', 'col3', 'col4', 'col5', 'col6']

# %%
print(mydata.groupby('col4').mean())
mydata.groupby('col4').mean().plot(y='col2', kind='bar', color='b', rot=90)
print(mydata.col2.describe())
# Out:
#                      col1       col2
# col4
# administrator  430.949367  38.746835
# artist         451.892857  31.392857
# doctor         533.714286  43.571429
# educator       466.905263  42.010526
# engineer       456.328358  36.388060
# entertainment  398.000000  29.222222
# executive      422.312500  38.718750
# healthcare     501.437500  41.562500
# homemaker      443.000000  32.571429
# lawyer         359.083333  36.750000
# librarian      486.588235  40.000000
# marketing      437.807692  37.615385
# none           368.666667  26.555556
# other          542.733333  34.523810
# programmer     435.530303  33.121212
# retired        515.714286  63.071429
# salesman       494.916667  35.666667
# scientist      465.129032  35.548387
# student        484.954082  22.081633
# technician     497.629630  33.148148
# writer         495.711111  36.311111
# count    943.000000
# mean      34.051962
# std       12.192740
# min        7.000000
# 25%       25.000000
# 50%       31.000000
# ...

# %%
from matplotlib.colors import ListedColormap as lmp
print(sns.color_palette("Paired", n_colors=21).as_hex())
mydata.groupby('col4').col1.count().plot(kind='pie',cmap=lmp(sns.color_palette("Paired", n_colors=21).as_hex()))
# Out:
# ['#a6cee3', '#1f78b4', '#b2df8a', '#33a02c', '#fb9a99', '#e31a1c', '#fdbf6f', '#ff7f00', '#cab2d6', '#6a3d9a', '#ffff99', '#b15928', '#a6cee3', '#1f78b4', '#b2df8a', '#33a02c', '#fb9a99', '#e31a1c', '#fdbf6f', '#ff7f00', '#cab2d6']
